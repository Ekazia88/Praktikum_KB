# %% [markdown]
# menggunakan pandas untuk menjalankan kodingan ini

# %%
import pandas as pd

# %% [markdown]
# Membaca file tersebut menggunakan pandas

# %%
data = pd.read_csv('player_stats.csv')

# %% [markdown]
# Membuat data tersebut menjadi dataframe

# %%
pd.DataFrame(data)
# Out:
#       Unnamed: 0  match_id  game_id  team  score_team opponent  score_opp  \
# 0              0     53658   119512  ZETA           5      DRX         13
# 1              1     53658   119512  ZETA           5      DRX         13
# 2              2     53658   119512  ZETA           5      DRX         13
# 3              3     53658   119512  ZETA           5      DRX         13
# 4              4     53658   119512  ZETA           5      DRX         13
# ...          ...       ...      ...   ...         ...      ...        ...
# 6225        6225     61192   137642    EG          13      PRX         10
# 6226        6226     61192   137642    EG          13      PRX         10
# 6227        6227     61192   137642    EG          13      PRX         10
# 6228        6228     61192   137642    EG          13      PRX         10
# 6229        6229     61192   137642    EG          13      PRX         10
#
#           win_lose     map       map_pick  ...  rating  acs kill death assist  \
# 0     opponent win  Ascent  opponent pick  ...    1.19  239   15    11      6
# 1     opponent win  Ascent  opponent pick  ...    0.84  234   15    14      6
# 2     opponent win  Ascent  opponent pick  ...    0.68  173   10    15      2
# 3     opponent win  Ascent  opponent pick  ...    0.63  142    8    15      4
# 4     opponent win  Ascent  opponent pick  ...    0.57  114    7    16      8
# ...            ...     ...            ...  ...     ...  ...  ...   ...    ...
# 6225      team win   Lotus      team pick  ...    1.43  244   23    13     10
# 6226      team win   Lotus      team pick  ...    1.26  338   26    18      5
# 6227      team win   Lotus      team pick  ...    1.09  198   16    16      1
# 6228      team win   Lotus      team pick  ...    0.86  180   13    17     15
# 6229      team win   Lotus      team pick  ...    0.86  118    9    13      8
#
#       kast%  adr  hs% fk fd
# 0       72%  146  16%  1  0
# 1       61%  145  32%  1  4
# 2       67%  123  18%  4  2
# 3       83%   92  29%  3  2
# 4       61%   63  13%  0  1
# ...     ...  ...  ... .. ..
# 6225    83%  162  46%  0  1
# 6226    78%  225  18%  7  3
# 6227    65%  131  36%  2  2
# 6228    74%  108  29%  2  3
# 6229    74%   82  30%  1  2
#
# [6230 rows x 23 columns]

# %% [markdown]
# Menampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka

# %%
data['acs'] = pd.to_numeric(data['acs'], errors='coerce', downcast='integer')
data.describe()
# Out:
#        Unnamed: 0      match_id        game_id   score_team    score_opp  \
# count  6230.00000   6230.000000    6230.000000  6230.000000  6230.000000
# mean   3114.50000  56190.330658  125572.073836    10.695827    10.695827
# std    1798.59042   3216.927760    7711.423206     3.438765     3.438765
# min       0.00000  52768.000000  117161.000000     0.000000     0.000000
# 25%    1557.25000  53561.000000  119246.000000     8.000000     8.000000
# 50%    3114.50000  53699.000000  119636.000000    13.000000    13.000000
# 75%    4671.75000  59969.000000  134549.000000    13.000000    13.000000
# max    6229.00000  61198.000000  137663.000000    21.000000    21.000000
#
#           player_id          acs         kill        death       assist
# count   6230.000000  6160.000000  6230.000000  6230.000000  6230.000000
# mean    4843.833868   197.908929    14.812520    14.819101     6.597592
# std     5696.784432    56.627896     5.319357     3.668542     4.042918
# min        4.000000    36.000000     2.000000     2.000000     0.000000
# 25%      733.000000   158.000000    11.000000    13.000000     4.000000
# 50%     2764.000000   194.000000    14.000000    15.000000     6.000000
# 75%     7718.000000   233.000000    18.000000    17.000000     9.000000
# max    39163.000000   441.000000    42.000000    33.000000    33.000000

# %% [markdown]
# Menampilkan 10 record pertama dari dataset dengan attribute bertipe angka.

# %%
data.head(10)
# Out:
#    Unnamed: 0  match_id  game_id  team  score_team opponent  score_opp  \
# 0           0     53658   119512  ZETA           5      DRX         13
# 1           1     53658   119512  ZETA           5      DRX         13
# 2           2     53658   119512  ZETA           5      DRX         13
# 3           3     53658   119512  ZETA           5      DRX         13
# 4           4     53658   119512  ZETA           5      DRX         13
# 5           5     53658   119512   DRX          13     ZETA          5
# 6           6     53658   119512   DRX          13     ZETA          5
# 7           7     53658   119512   DRX          13     ZETA          5
# 8           8     53658   119512   DRX          13     ZETA          5
# 9           9     53658   119512   DRX          13     ZETA          5
#
#        win_lose     map       map_pick  ...  rating    acs kill death  assist  \
# 0  opponent win  Ascent  opponent pick  ...    1.19  239.0   15    11       6
# 1  opponent win  Ascent  opponent pick  ...    0.84  234.0   15    14       6
# 2  opponent win  Ascent  opponent pick  ...    0.68  173.0   10    15       2
# 3  opponent win  Ascent  opponent pick  ...    0.63  142.0    8    15       4
# 4  opponent win  Ascent  opponent pick  ...    0.57  114.0    7    16       8
# 5      team win  Ascent      team pick  ...    1.67  257.0   15     9      20
# 6      team win  Ascent      team pick  ...    1.30  275.0   18    11       4
# 7      team win  Ascent      team pick  ...    1.27  299.0   17    15       8
# 8      team win  Ascent      team pick  ...    1.06  168.0   11    10       3
# 9      team win  Ascent      team pick  ...    0.87  125.0   10    10       0
#
#    kast%  adr  hs% fk fd
# 0    72%  146  16%  1  0
# 1    61%  145  32%  1  4
# 2    67%  123  18%  4  2
# 3    83%   92  29%  3  2
# 4    61%   63  13%  0  1
# 5    83%  172  30%  1  2
# 6    72%  167  17%  5  4
# 7    83%  190  28%  2  1
# 8    67%   95  31%  1  0
# 9    67%   63  19%  0  2
#
# [10 rows x 23 columns]

# %% [markdown]
# Menampilkan Informasi jumlah record informasi jumlah record, jumlah attribute, nama attribute, jumlah attribute dengan tipe angka kedalam dictionary

# %%
info = {}
info['Jumlah record'] = len(data)
info['Jumlah Atrribute'] = data.shape[1]
info['Nama Atributte'] = data.columns
info['Jumlah Atrribute bertipe angka'] = data.select_dtypes(include=['int', 'float']).shape[1]
pd.DataFrame.from_dict(info)
# Out:
#     Jumlah record  Jumlah Atrribute Nama Atributte  \
# 0            6230                23     Unnamed: 0
# 1            6230                23       match_id
# 2            6230                23        game_id
# 3            6230                23           team
# 4            6230                23     score_team
# 5            6230                23       opponent
# 6            6230                23      score_opp
# 7            6230                23       win_lose
# 8            6230                23            map
# 9            6230                23       map_pick
# 10           6230                23      player_id
# 11           6230                23         player
# 12           6230                23          agent
# 13           6230                23         rating
# 14           6230                23            acs
# 15           6230                23           kill
# 16           6230                23          death
# 17           6230                23         assist
# 18           6230                23          kast%
# 19           6230                23            adr
# 20           6230                23            hs%
# 21           6230                23             fk
# 22           6230                23             fd
#
#     Jumlah Atrribute bertipe angka
# 0                               10
# 1                               10
# 2                               10
# 3                               10
# 4                               10
# 5                               10
# 6                               10
# 7                               10
# 8                               10
# 9                               10
# 10                              10
# 11                              10
# 12                              10
# 13                              10
# 14                              10
# 15                              10
# 16                              10
# 17                              10
# 18                              10
# 19                              10
# 20                              10
# 21                              10
# 22                              10

# %% [markdown]
# Memapilkan nilai dataset menggunakan loc

# %%
data.loc[134:,'team':]
# Out:
#       team  score_team opponent  score_opp      win_lose     map  \
# 134   ZETA          13      RRQ         10      team win  Ascent
# 135    RRQ          10     ZETA         13  opponent win  Ascent
# 136    RRQ          10     ZETA         13  opponent win  Ascent
# 137    RRQ          10     ZETA         13  opponent win  Ascent
# 138    RRQ          10     ZETA         13  opponent win  Ascent
# ...    ...         ...      ...        ...           ...     ...
# 6225    EG          13      PRX         10      team win   Lotus
# 6226    EG          13      PRX         10      team win   Lotus
# 6227    EG          13      PRX         10      team win   Lotus
# 6228    EG          13      PRX         10      team win   Lotus
# 6229    EG          13      PRX         10      team win   Lotus
#
#            map_pick  player_id   player    agent rating    acs  kill  death  \
# 134   opponent pick       1000     crow     kayo   0.68  147.0     9     17
# 135       team pick       7403     EJAY     jett   1.38  290.0    23     16
# 136       team pick       4871   xffero     sova   1.15  223.0    19     14
# 137       team pick       9735      2ge    astra   1.01  139.0    10     15
# 138       team pick       7764  Lmemore  killjoy   0.95  191.0    15     17
# ...             ...        ...      ...      ...    ...    ...   ...    ...
# 6225      team pick      26171   Demon1    astra   1.43  244.0    23     13
# 6226      team pick       3993  jawgemo     raze   1.26  338.0    26     18
# 6227      team pick        604  Boostio  killjoy   1.09  198.0    16     16
# 6228      team pick      11225    Ethan     skye   0.86  180.0    13     17
# 6229      team pick        619      C0M    viper   0.86  118.0     9     13
#
#       assist kast%  adr  hs% fk fd
# 134       16   70%   96  12%  2  1
# 135        4   70%  180  15%  3  4
# 136        5   83%  136  16%  2  1
# 137       15   87%   86  28%  1  2
# 138        3   83%  131  28%  4  2
# ...      ...   ...  ...  ... .. ..
# 6225      10   83%  162  46%  0  1
# 6226       5   78%  225  18%  7  3
# 6227       1   65%  131  36%  2  2
# 6228      15   74%  108  29%  2  3
# 6229       8   74%   82  30%  1  2
#
# [6096 rows x 20 columns]

# %% [markdown]
# Menampilkan nilai data set menggunakan iloc

# %%
data.iloc[134:,4:]
# Out:
#       score_team opponent  score_opp      win_lose     map       map_pick  \
# 134           13      RRQ         10      team win  Ascent  opponent pick
# 135           10     ZETA         13  opponent win  Ascent      team pick
# 136           10     ZETA         13  opponent win  Ascent      team pick
# 137           10     ZETA         13  opponent win  Ascent      team pick
# 138           10     ZETA         13  opponent win  Ascent      team pick
# ...          ...      ...        ...           ...     ...            ...
# 6225          13      PRX         10      team win   Lotus      team pick
# 6226          13      PRX         10      team win   Lotus      team pick
# 6227          13      PRX         10      team win   Lotus      team pick
# 6228          13      PRX         10      team win   Lotus      team pick
# 6229          13      PRX         10      team win   Lotus      team pick
#
#       player_id   player    agent rating    acs  kill  death  assist kast%  \
# 134        1000     crow     kayo   0.68  147.0     9     17      16   70%
# 135        7403     EJAY     jett   1.38  290.0    23     16       4   70%
# 136        4871   xffero     sova   1.15  223.0    19     14       5   83%
# 137        9735      2ge    astra   1.01  139.0    10     15      15   87%
# 138        7764  Lmemore  killjoy   0.95  191.0    15     17       3   83%
# ...         ...      ...      ...    ...    ...   ...    ...     ...   ...
# 6225      26171   Demon1    astra   1.43  244.0    23     13      10   83%
# 6226       3993  jawgemo     raze   1.26  338.0    26     18       5   78%
# 6227        604  Boostio  killjoy   1.09  198.0    16     16       1   65%
# 6228      11225    Ethan     skye   0.86  180.0    13     17      15   74%
# 6229        619      C0M    viper   0.86  118.0     9     13       8   74%
#
#       adr  hs% fk fd
# 134    96  12%  2  1
# 135   180  15%  3  4
# 136   136  16%  2  1
# 137    86  28%  1  2
# 138   131  28%  4  2
# ...   ...  ... .. ..
# 6225  162  46%  0  1
# 6226  225  18%  7  3
# 6227  131  36%  2  2
# 6228  108  29%  2  3
# 6229   82  30%  1  2
#
# [6096 rows x 19 columns]

# %% [markdown]
# Menampilkan jumlah label dengan atribut objek

# %%
kolobjek = data.select_dtypes(include='object')
jml_kol_objk = kolobjek.nunique()
pd.DataFrame({'Jumlah Kolom Objek ': jml_kol_objk})
# Out:
#           Jumlah Kolom Objek
# team                       36
# opponent                   36
# win_lose                    2
# map                         8
# map_pick                    2
# player                    197
# agent                      21
# rating                    185
# kast%                      71
# adr                       222
# hs%                        68
# fk                         14
# fd                         13
